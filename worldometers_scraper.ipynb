# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime

# %%
URL = 'https://www.worldometers.info/coronavirus/#countries'

headers = {
  "User-Agents":
    'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.76 Safari/537.36'}

# %%
def extract_global(soup):
  counts = [n.text for n in soup.find_all('div', class_= 'maincounter-number')]
  return counts

# %%
def stats_global(soup):
  counts = extract_global(soup)
  data = {}
  data['totalCases'] = counts[0]
  data['totalDeaths'] = counts[1]
  data['totalRecovered'] = counts[2]

  print("GLOBAL STATISTICS")
  print()

  print("Total Cases: %s" %data['totalCases'])
  print("Total Deaths: %s" %data['totalDeaths'])
  print("Total Recovered: %s" %data['totalRecovered'])
  print()
stats_global(soup)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-055e33efa592> in <module>
#      13   print("Total Recovered: %s" %data['totalRecovered'])
#      14   print()
# ---> 15 stats_global(soup)
#
# NameError: name 'soup' is not defined

# %%
def extract_countries(soup):
  countries = []
  table = soup.find('table')
  tableBody = table.find('tbody')

  rows = tableBody.find_all('tr')

  for row in rows:
    cols = row.find_all('td')
    cols = [ele.text.strip() for ele in cols]
    countries.append([ele for ele in cols if ele])

  for country in countries[:100]:

    if country[0].isnumeric():
      if len(country) > 5:
        country.pop(0)
        get_country(country[0], country)
    else:
      get_country(country[0], country)

# %%
       
def get_country(country, data):
  print("__________________")
  print(country)
  print("__________________")
  print()
  print("New Cases: %s" % data[2])
  print("Total Cases: %s" % data[1])
  print("Total Recovered: %s" % data[5])
  print("Total Deaths: %s" % data[3])

# %%
def scrapper_data_covid():
  web = requests.get(URL, headers, timeout=5)
  if web.status_code != 200:
      return None
  soup = BeautifulSoup(web.content, "html.parser")

  d = datetime.now().strftime("%m/%d/%Y -- %I:%M %p")

  print("Updated at: %s" %d)

  stats_global(soup)
  extract_countries(soup)


scrapper_data_covid()
# Out:
# Updated at: 04/03/2021 -- 04:47 PM
# GLOBAL STATISTICS
#
# Total Cases:
# 130,998,190
#
# Total Deaths:
# 2,853,280
#
# Total Recovered:
# 105,447,782
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-510f0911cc98> in <module>
#      13
#      14
# ---> 15 scrapper_data_covid()
#
# <ipython-input-5-510f0911cc98> in scrapper_data_covid()
#      10
#      11   stats_global(soup)
# ---> 12   extract_countries(soup)
#      13
#      14
#
# NameError: name 'extract_countries' is not defined

# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime

URL = 'https://www.worldometers.info/coronavirus/#countries'

headers = {
  "User-Agents": 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.76 Safari/537.36'}

def extract_global(soup):
  counts = [n.text for n in soup.find_all('div', class_= 'maincounter-number')]
  return counts

def stats_global(soup):
  counts = extract_global(soup)
  data = {}
  data['totalCases'] = counts[0]
  data['totalDeaths'] = counts[1]
  data['totalRecovered'] = counts[2]

  print("GLOBAL STATISTICS")
  print()

  print("Total Cases: %s" %data['totalCases'])
  print("Total Deaths: %s" %data['totalDeaths'])
  print("Total Recovered: %s" %data['totalRecovered'])
  print()


def extract_countries(soup):
  countries = []
  table = soup.find('table')
  tableBody = table.find('tbody')

  rows = tableBody.find_all('tr')

  for row in rows:
    cols = row.find_all('td')
    cols = [ele.text.strip() for ele in cols]
    countries.append([ele for ele in cols if ele])

  for country in countries[:100]:

    if country[0].isnumeric():
      if len(country) > 5:
        country.pop(0)
        get_country(country[0], country)
    else:
      get_country(country[0], country)
     
       
def get_country(country, data):
  print("__________________")
  print(country)
  print("__________________")
  print()
  print("New Cases: %s" % data[2])
  print("Total Cases: %s" % data[1])
  print("Total Recovered: %s" % data[5])
  print("Total Deaths: %s" % data[3])


def scrapper_data_covid():
  web = requests.get(URL, headers, timeout=5)
  if web.status_code != 200:
      return None
  soup = BeautifulSoup(web.content, "html.parser")

  d = datetime.now().strftime("%m/%d/%Y -- %I:%M %p")

  print("Updated at: %s" %d)

  stats_global(soup)
  extract_countries(soup)


scrapper_data_covid()
# Out:
# Updated at: 04/03/2021 -- 04:56 PM
# GLOBAL STATISTICS
#
# Total Cases:
# 130,998,190
#
# Total Deaths:
# 2,853,280
#
# Total Recovered:
# 105,447,782
#
#
# __________________
# North America
# __________________
#
# New Cases: +4,406
# Total Cases: 36,057,695
# Total Recovered: 27,758,833
# Total Deaths: 823,100
# __________________
# South America
# __________________
#
# New Cases: +620
# Total Cases: 21,428,341
# Total Recovered: 19,076,070
# Total Deaths: 560,602
# __________________
# Asia
# __________________
#
# New Cases: +83,552
# Total Cases: 28,983,511
# Total Recovered: 26,378,281
# Total Deaths: 431,901
# __________________
# Europe
# __________________
#
# New Cases: +105,157
# Total Cases: 40,182,782
# Total Recovered: 28,354,863
# Total Deaths: 922,816
# __________________
# Africa
# __________________
#
# New Cases: +495
# Total Cases: 4,287,412
# Total Recovered: 3,844,442
# Total Deaths: 113,704
# __________________
# Oceania
# __________________
#
# New Cases: +158
# Total Cases: 57,728
# Total Recovered: +9
# Total Deaths: 1,142
# __________________
# World
# __________________
#
# New Cases: +194,388
# Total Cases: 130,998,190
# Total Recovered: 105,447,782
# Total Deaths: 2,853,280
# __________________
# USA
# __________________
#
# New Cases: +279
# Total Cases: 31,316,247
# Total Recovered: 23,825,896
# Total Deaths: 567,611
# __________________
# Brazil
# __________________
#
# New Cases: 328,366
# Total Cases: 12,912,379
# Total Recovered: 8,318
# Total Deaths: 11,276,628
# __________________
# India
# __________________
#
# New Cases: +22,008
# Total Cases: 12,413,137
# Total Recovered: 11,577,647
# Total Deaths: 164,231
# __________________
# France
# __________________
#
# New Cases: 96,280
# Total Cases: 4,741,759
# Total Recovered: 5,254
# Total Deaths: 297,734
# __________________
# Russia
# __________________
#
# New Cases: +9,021
# Total Cases: 4,572,077
# Total Recovered: 4,195,869
# Total Deaths: 100,017
# __________________
# UK
# __________________
#
# New Cases: 126,816
# Total Cases: 4,353,668
# Total Recovered: 517
# Total Deaths: 3,873,487
# __________________
# Italy
# __________________
#
# New Cases: 110,328
# Total Cases: 3,629,000
# Total Recovered: 3,704
# Total Deaths: 2,953,377
# __________________
# Turkey
# __________________
#
# New Cases: 31,892
# Total Cases: 3,400,296
# Total Recovered: 2,182
# Total Deaths: 3,059,462
# __________________
# Spain
# __________________
#
# New Cases: 75,541
# Total Cases: 3,291,394
# Total Recovered: 1,843
# Total Deaths: 3,054,725
# __________________
# Germany
# __________________
#
# New Cases: +1,992
# Total Cases: 2,874,371
# Total Recovered: 2,560,400
# Total Deaths: 77,431
# __________________
# Colombia
# __________________
#
# New Cases: 63,777
# Total Cases: 2,428,048
# Total Recovered: 2,603
# Total Deaths: 2,300,887
# __________________
# Poland
# __________________
#
# New Cases: +28,073
# Total Cases: 2,415,584
# Total Recovered: 1,945,994
# Total Deaths: 54,737
# __________________
# Argentina
# __________________
#
# New Cases: 56,023
# Total Cases: 2,373,153
# Total Recovered: 3,619
# Total Deaths: 2,121,954
# __________________
# Mexico
# __________________
#
# New Cases: +3,089
# Total Cases: 2,247,357
# Total Recovered: 1,781,629
# Total Deaths: 203,854
# __________________
# Iran
# __________________
#
# New Cases: +11,420
# Total Cases: 1,920,394
# Total Recovered: 1,642,418
# Total Deaths: 62,999
# __________________
# Ukraine
# __________________
#
# New Cases: +20,341
# Total Cases: 1,731,971
# Total Recovered: 1,342,536
# Total Deaths: 34,075
# __________________
# Peru
# __________________
#
# New Cases: 52,331
# Total Cases: 1,568,345
# Total Recovered: 2,357
# Total Deaths: 1,485,582
# __________________
# South Africa
# __________________
#
# New Cases: 52,946
# Total Cases: 1,550,724
# Total Recovered: 546
# Total Deaths: 1,475,398
# __________________
# Czechia
# __________________
#
# New Cases: +3,809
# Total Cases: 1,549,734
# Total Recovered: 1,389,189
# Total Deaths: 26,867
# __________________
# Indonesia
# __________________
#
# New Cases: +4,345
# Total Cases: 1,527,524
# Total Recovered: 1,366,214
# Total Deaths: 41,242
# __________________
# Netherlands
# __________________
#
# New Cases: +7,628
# Total Cases: 1,295,324
# Total Recovered: N/A
# Total Deaths: 16,606
# __________________
# Chile
# __________________
#
# New Cases: 23,421
# Total Cases: 1,011,485
# Total Recovered: 2,804
# Total Deaths: 942,413
# __________________
# Canada
# __________________
#
# New Cases: 23,008
# Total Cases: 990,604
# Total Recovered: 704
# Total Deaths: 916,422
# __________________
# Romania
# __________________
#
# New Cases: +5,498
# Total Cases: 970,224
# Total Recovered: 867,663
# Total Deaths: 23,973
# __________________
# Belgium
# __________________
#
# New Cases: +4,665
# Total Cases: 892,585
# Total Recovered: 57,671
# Total Deaths: 23,083
# __________________
# Iraq
# __________________
#
# New Cases: +5,379
# Total Cases: 868,200
# Total Recovered: 773,232
# Total Deaths: 14,430
# __________________
# Israel
# __________________
#
# New Cases: 6,220
# Total Cases: 833,707
# Total Recovered: 368
# Total Deaths: 820,906
# __________________
# Portugal
# __________________
#
# New Cases: 16,868
# Total Cases: 822,862
# Total Recovered: 131
# Total Deaths: 779,655
# __________________
# Sweden
# __________________
#
# New Cases: 13,498
# Total Cases: 813,191
# Total Recovered: N/A
# Total Deaths: N/A
# __________________
# Philippines
# __________________
#
# New Cases: +12,576
# Total Cases: 784,043
# Total Recovered: 604,905
# Total Deaths: 13,423
# __________________
# Pakistan
# __________________
#
# New Cases: +4,723
# Total Cases: 682,888
# Total Recovered: 609,691
# Total Deaths: 14,697
# __________________
# Hungary
# __________________
#
# New Cases: +8,637
# Total Cases: 679,413
# Total Recovered: 415,601
# Total Deaths: 21,504
# __________________
# Bangladesh
# __________________
#
# New Cases: +5,683
# Total Cases: 630,277
# Total Recovered: 549,775
# Total Deaths: 9,213
# __________________
# Jordan
# __________________
#
# New Cases: 7,039
# Total Cases: 622,833
# Total Recovered: 729
# Total Deaths: 525,703
# __________________
# Serbia
# __________________
#
# New Cases: +4,133
# Total Cases: 614,365
# Total Recovered: 510,932
# Total Deaths: 5,422
# __________________
# Switzerland
# __________________
#
# New Cases: 10,351
# Total Cases: 605,342
# Total Recovered: 158
# Total Deaths: 548,375
# __________________
# Austria
# __________________
#
# New Cases: +3,283
# Total Cases: 556,012
# Total Recovered: 509,550
# Total Deaths: 9,434
# __________________
# Morocco
# __________________
#
# New Cases: 8,835
# Total Cases: 497,257
# Total Recovered: 237
# Total Deaths: 484,224
# __________________
# Japan
# __________________
#
# New Cases: +2,707
# Total Cases: 480,165
# Total Recovered: 449,091
# Total Deaths: 9,213
# __________________
# Lebanon
# __________________
#
# New Cases: 6,346
# Total Cases: 474,925
# Total Recovered: 925
# Total Deaths: 377,136
# __________________
# UAE
# __________________
#
# New Cases: +2,084
# Total Cases: 468,023
# Total Recovered: 452,321
# Total Deaths: 1,504
# __________________
# Saudi Arabia
# __________________
#
# New Cases: +684
# Total Cases: 392,009
# Total Recovered: 379,312
# Total Deaths: 6,690
# __________________
# Slovakia
# __________________
#
# New Cases: +748
# Total Cases: 364,622
# Total Recovered: 255,300
# Total Deaths: 9,948
# __________________
# Panama
# __________________
#
# New Cases: 6,126
# Total Cases: 355,850
# Total Recovered: 105
# Total Deaths: 344,701
# __________________
# Bulgaria
# __________________
#
# New Cases: 13,438
# Total Cases: 350,340
# Total Recovered: 753
# Total Deaths: 266,091
# __________________
# Malaysia
# __________________
#
# New Cases: +1,638
# Total Cases: 349,610
# Total Recovered: 333,892
# Total Deaths: 1,286
# __________________
# Ecuador
# __________________
#
# New Cases: 16,910
# Total Cases: 332,038
# Total Recovered: 555
# Total Deaths: 281,684
# __________________
# Belarus
# __________________
#
# New Cases: 2,267
# Total Cases: 324,694
# Total Recovered: 34,370
# Total Deaths: 315,226
# __________________
# Georgia
# __________________
#
# New Cases: +580
# Total Cases: 283,369
# Total Recovered: 274,145
# Total Deaths: 3,804
# __________________
# Croatia
# __________________
#
# New Cases: +2,234
# Total Cases: 278,650
# Total Recovered: 258,872
# Total Deaths: 6,025
# __________________
# Nepal
# __________________
#
# New Cases: +128
# Total Cases: 277,768
# Total Recovered: 273,123
# Total Deaths: 3,032
# __________________
# Bolivia
# __________________
#
# New Cases: +620
# Total Cases: 273,947
# Total Recovered: 223,760
# Total Deaths: 12,305
# __________________
# Greece
# __________________
#
# New Cases: 8,232
# Total Cases: 270,230
# Total Recovered: 753
# Total Deaths: 228,965
# __________________
# Azerbaijan
# __________________
#
# New Cases: +2,392
# Total Cases: 268,174
# Total Recovered: 240,870
# Total Deaths: 3,648
# __________________
# Tunisia
# __________________
#
# New Cases: 8,890
# Total Cases: 256,931
# Total Recovered: 336
# Total Deaths: 218,377
# __________________
# Dominican Republic
# __________________
#
# New Cases: 3,334
# Total Cases: 253,781
# Total Recovered: 158
# Total Deaths: 213,339
# __________________
# Kazakhstan
# __________________
#
# New Cases: +2,122
# Total Cases: 251,053
# Total Recovered: 222,606
# Total Deaths: 3,085
# __________________
# Palestine
# __________________
#
# New Cases: +1,589
# Total Cases: 248,482
# Total Recovered: 220,418
# Total Deaths: 2,681
# __________________
# Ireland
# __________________
#
# New Cases: 4,713
# Total Cases: 237,187
# Total Recovered: 60
# Total Deaths: 23,364
# __________________
# Kuwait
# __________________
#
# New Cases: 1,327
# Total Cases: 234,754
# Total Recovered: 241
# Total Deaths: 219,257
# __________________
# Moldova
# __________________
#
# New Cases: 5,048
# Total Cases: 233,136
# Total Recovered: 323
# Total Deaths: 211,803
# __________________
# Denmark
# __________________
#
# New Cases: +745
# Total Cases: 232,718
# Total Recovered: 221,004
# Total Deaths: 2,428
# __________________
# Slovenia
# __________________
#
# New Cases: +1,296
# Total Cases: 219,420
# Total Recovered: 201,446
# Total Deaths: 4,068
# __________________
# Lithuania
# __________________
#
# New Cases: +985
# Total Cases: 218,878
# Total Recovered: 201,598
# Total Deaths: 3,602
# __________________
# Paraguay
# __________________
#
# New Cases: 4,294
# Total Cases: 217,886
# Total Recovered: 431
# Total Deaths: 178,804
# __________________
# Costa Rica
# __________________
#
# New Cases: 2,957
# Total Cases: 216,764
# Total Recovered: 163
# Total Deaths: 192,699
# __________________
# Ethiopia
# __________________
#
# New Cases: 2,915
# Total Cases: 211,314
# Total Recovered: 829
# Total Deaths: 159,929
# __________________
# Egypt
# __________________
#
# New Cases: 12,084
# Total Cases: 203,546
# Total Recovered: 90
# Total Deaths: 155,448
# __________________
# Armenia
# __________________
#
# New Cases: +1,192
# Total Cases: 196,044
# Total Recovered: 175,401
# Total Deaths: 3,575
# __________________
# Guatemala
# __________________
#
# New Cases: 6,875
# Total Cases: 195,036
# Total Recovered: 5
# Total Deaths: 178,659
# __________________
# Honduras
# __________________
#
# New Cases: 4,622
# Total Cases: 189,726
# Total Recovered: 468
# Total Deaths: 73,308
# __________________
# Qatar
# __________________
#
# New Cases: +870
# Total Cases: 182,548
# Total Recovered: 165,471
# Total Deaths: 301
# __________________
# Bosnia and Herzegovina
# __________________
#
# New Cases: 6,763
# Total Cases: 173,478
# Total Recovered: 53,126
# Total Deaths: 131,726
# __________________
# Nigeria
# __________________
#
# New Cases: 2,058
# Total Cases: 163,063
# Total Recovered: 11
# Total Deaths: 151,835
# __________________
# Venezuela
# __________________
#
# New Cases: 1,629
# Total Cases: 162,730
# Total Recovered: 198
# Total Deaths: 149,459
# __________________
# Libya
# __________________
#
# New Cases: 2,684
# Total Cases: 161,088
# Total Recovered: 23,207
# Total Deaths: 148,288
# __________________
# Oman
# __________________
#
# New Cases: 1,681
# Total Cases: 160,018
# Total Recovered: 160
# Total Deaths: 144,639
# __________________
# Bahrain
# __________________
#
# New Cases: 527
# Total Cases: 146,454
# Total Recovered: 66
# Total Deaths: 136,827
# __________________
# Myanmar
# __________________
#
# New Cases: 3,206
# Total Cases: 142,479
# Total Recovered: 2,605
# Total Deaths: 131,810
# __________________
# Kenya
# __________________
#
# New Cases: 2,186
# Total Cases: 136,893
# Total Recovered: 185
# Total Deaths: 93,430
# __________________
# North Macedonia
# __________________
#
# New Cases: 3,860
# Total Cases: 132,740
# Total Recovered: 124
# Total Deaths: 108,197
# __________________
# Albania
# __________________
#
# New Cases: 2,247
# Total Cases: 125,842
# Total Recovered: 18
# Total Deaths: 92,500
# __________________
# Algeria
# __________________
#
# New Cases: 3,099
# Total Cases: 117,429
# Total Recovered: 16
# Total Deaths: 81,729
# __________________
# Uruguay
# __________________
#
# New Cases: 1,041
# Total Cases: 111,568
# Total Recovered: 360
# Total Deaths: 87,039
# __________________
# Estonia
# __________________
#
# New Cases: +519
# Total Cases: 108,937
# Total Recovered: 85,900
# Total Deaths: 931
# __________________
# S. Korea
# __________________
#
# New Cases: +542
# Total Cases: 104,736
# Total Recovered: 96,196
# Total Deaths: 1,740
# __________________
# Latvia
# __________________
#
# New Cases: +279
# Total Cases: 103,867
# Total Recovered: 94,101
# Total Deaths: 1,923
# __________________
# Norway
# __________________
#
# New Cases: +450
# Total Cases: 97,860
# Total Recovered: 17,164
# Total Deaths: 673
# __________________
# Sri Lanka
# __________________
#
# New Cases: 575
# Total Cases: 93,128
# Total Recovered: +320
# Total Deaths: +4
# __________________
# Montenegro
# __________________
#
# New Cases: +316
# Total Cases: 92,222
# Total Recovered: 85,153
# Total Deaths: 1,303
# __________________
# Ghana
# __________________
#
# New Cases: 744
# Total Cases: 90,674
# Total Recovered: 39
# Total Deaths: 88,426
# __________________
# Kyrgyzstan
# __________________
#
# New Cases: +142
# Total Cases: 88,842
# Total Recovered: 85,077
# Total Deaths: 1,502
